# %%
#sentdex
import pixiedust
import pandas_datareader as web
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>

# %%
# %%pixie_debugger
# #Get the stock quote
# try:
#     df = web.DataReader('AAPL', data_source='yahoo', start='2019-01-01', end='2020-01-01')
# except Exception as e:
#     print('error: {}'.format(e))
# #Show the data
# print(df.head())
# df['Close5'] = 0
# df.Close5[0:-5] = df.Close[5:]
# df['20ma'] = df['Adj Close'].rolling(window=20, min_periods=0).mean()
# print(df[['Close','Close5', 'Adj Close', '20ma']][:10])
# print(df[['Close','Close5', 'Adj Close', '20ma']].tail(10))
# Out:
# <script>
#     //Marker 9f6a1a5b
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker 9f6a1a5b")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close  \
# Date
# 1999-12-31  3.674107  3.553571  3.604911  3.671875   40952800.0   3.187337
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200.0   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400.0   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400.0   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200.0   2.945139
#
#               Close5      20ma
# Date
# 1999-12-31  3.553571  3.187337
# 2000-01-03  3.491071  3.328781
# 2000-01-04  3.312500  3.278404
# 2000-01-05  3.113839  3.264841
# 2000-01-06  3.455357  3.200901

# %%
df[:-5].to_excel("stock_data.xlsx")

# %%
#richard moglen
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt
from pandas_datareader import data as pdr

# %%
yf.pdr_override()
stock = 'QQQ'

start = dt.datetime(2019,1,1)
now = dt.datetime.now()

df = pdr.get_data_yahoo(stock,start,now)
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  154.470001  154.979996  152.710007  154.259995  152.673813
# 2019-01-02  150.990005  155.750000  150.880005  154.880005  153.287430
# 2019-01-03  152.600006  153.259995  149.490005  149.820007  148.279449
# 2019-01-04  152.339996  157.000000  151.740005  156.229996  154.623550
# 2019-01-07  156.619995  158.860001  156.110001  158.089996  156.464417
# 2019-01-08  159.539993  160.110001  157.199997  159.520004  157.879700
# 2019-01-09  160.139999  161.520004  159.470001  160.820007  159.166367
# 2019-01-10  159.600006  161.369995  158.699997  161.279999  159.621628
# 2019-01-11  160.330002  160.860001  159.789993  160.690002  159.037689
# 2019-01-14  159.330002  159.960007  158.589996  159.270004  157.632278
# 2019-01-15  160.000000  162.600006  159.910004  162.380005  160.710312
# ...

# %%
ma=50
smaString="Sma_"+str(ma)
df[smaString] = df.iloc[:,4].rolling(window=ma).mean()
print(df)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  154.470001  154.979996  152.710007  154.259995  152.673813
# 2019-01-02  150.990005  155.750000  150.880005  154.880005  153.287430
# 2019-01-03  152.600006  153.259995  149.490005  149.820007  148.279449
# 2019-01-04  152.339996  157.000000  151.740005  156.229996  154.623550
# 2019-01-07  156.619995  158.860001  156.110001  158.089996  156.464417
# 2019-01-08  159.539993  160.110001  157.199997  159.520004  157.879700
# 2019-01-09  160.139999  161.520004  159.470001  160.820007  159.166367
# 2019-01-10  159.600006  161.369995  158.699997  161.279999  159.621628
# 2019-01-11  160.330002  160.860001  159.789993  160.690002  159.037689
# 2019-01-14  159.330002  159.960007  158.589996  159.270004  157.632278
# 2019-01-15  160.000000  162.600006  159.910004  162.380005  160.710312
# 2019-01-16  162.649994  163.779999  162.289993  162.350006  160.680618
# ...

# %%
df=df.iloc[ma:]
print(df)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-14  177.130005  177.339996  176.660004  176.710007  174.892944
# 2019-03-15  177.399994  178.880005  177.279999  178.350006  176.516098
# 2019-03-18  177.949997  178.990005  177.589996  178.449997  176.936478
# 2019-03-19  179.179993  180.000000  178.289993  179.050003  177.531403
# 2019-03-20  179.059998  180.860001  178.240005  179.759995  178.235397
# 2019-03-21  179.220001  182.830002  179.199997  182.570007  181.021545
# 2019-03-22  181.779999  182.270004  178.369995  178.559998  177.045563
# 2019-03-25  177.910004  178.839996  176.929993  178.220001  176.708450
# 2019-03-26  179.600006  180.690002  178.139999  179.050003  177.531403
# 2019-03-27  179.320007  179.720001  176.600006  177.899994  176.391144
# 2019-03-28  178.360001  178.979996  177.240005  178.309998  176.797668
# 2019-03-29  179.690002  179.830002  178.589996  179.660004  178.136230
# ...

# %%
numH=0
numC=0

for i in df.index:
    if df['Adj Close'][i]>df[smaString][i]:
        print("The close is higher")
        numH+=1
    else:
        print("The close is lower")
        numC+=1
print(str(numH))
print(str(numC))
# Out:
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# ...
